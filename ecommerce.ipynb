# %% [markdown]
# E-commerce Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Order Details.csv")
data
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category
# 0     B-25601  1275.0 -1148.0         7    Furniture         Bookcases
# 1     B-25601    66.0   -12.0         5     Clothing             Stole
# 2     B-25601     8.0    -2.0         3     Clothing       Hankerchief
# 3     B-25601    80.0   -56.0         4  Electronics  Electronic Games
# 4     B-25602   168.0  -111.0         2  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-26099   835.0   267.0         5  Electronics            Phones
# 1496  B-26099  2366.0   552.0         5     Clothing          Trousers
# 1497  B-26100   828.0   230.0         2    Furniture            Chairs
# 1498  B-26100    34.0    10.0         2     Clothing           T-shirt
# 1499  B-26100    72.0    16.0         2     Clothing             Shirt
#
# [1500 rows x 6 columns]

# %%
data.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category
# 0  B-25601  1275.0 -1148.0         7    Furniture         Bookcases
# 1  B-25601    66.0   -12.0         5     Clothing             Stole
# 2  B-25601     8.0    -2.0         3     Clothing       Hankerchief
# 3  B-25601    80.0   -56.0         4  Electronics  Electronic Games
# 4  B-25602   168.0  -111.0         2  Electronics            Phones

# %%
data.describe()
# Out:
#             Amount       Profit     Quantity
# count  1500.000000  1500.000000  1500.000000
# mean    287.668000    15.970000     3.743333
# std     461.050488   169.140565     2.184942
# min       4.000000 -1981.000000     1.000000
# 25%      45.000000    -9.250000     2.000000
# 50%     118.000000     9.000000     3.000000
# 75%     322.000000    38.000000     5.000000
# max    5729.000000  1698.000000    14.000000

# %%
data.isnull().sum()
# Out:
# Order ID        0
# Amount          0
# Profit          0
# Quantity        0
# Category        0
# Sub-Category    0
# dtype: int64

# %%
total_orders = data['Order ID'].nunique()
print("Total Orders:", total_orders)
# Out:
# Total Orders: 500

# %%
#total revenue
total_revenue = data['Amount'].sum()
print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 431502.0

# %%
#Average Order Amount
average_order_amount = data['Amount'].mean()
print("Average Order Amount:", average_order_amount)
# Out:
# Average Order Amount: 287.668

# %%
#Popular Category
popular_categories = data['Category'].value_counts().head(5)
print("Most Popular Categories:")
print(popular_categories)
# Out:
# Most Popular Categories:
# Clothing       949
# Electronics    308
# Furniture      243
# Name: Category, dtype: int64

# %%
popular_subcategories = data['Sub-Category'].value_counts().head(5)
print("Most Popular Sub-Categories:")
print(popular_subcategories)
# Out:
# Most Popular Sub-Categories:
# Saree          210
# Hankerchief    198
# Stole          192
# Phones          83
# Bookcases       79
# Name: Sub-Category, dtype: int64

# %%
#Histogram for order amount
plt.figure(figsize=(10, 6))
plt.hist(data['Amount'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Order Amount')
plt.ylabel('Frequency')
plt.title('Distribution of Order Amounts')
plt.show()

# %%
#Bar plot for popular categories
plt.figure(figsize=(10, 6))
popular_categories.plot(kind='bar', color='green')
plt.xlabel('Category')
plt.ylabel('Number of Orders')
plt.title('Most Popular Categories')
plt.show()

# %%
#Bar plot for popular subcategories
plt.figure(figsize=(10, 6))
popular_subcategories.plot(kind='bar', color='red')
plt.xlabel('Sub_Category')
plt.ylabel('Number of Orders')
plt.title('Most Popular Categories')
plt.show()

# %%
# Pie chart for distribution of subcategories
subcategory_distribution = data['Sub-Category'].value_counts()
plt.figure(figsize=(10, 6))
plt.pie(subcategory_distribution, labels=subcategory_distribution.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Distribution of Subcategories')
plt.show()
